# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=pd.read_csv("Bihar_Election_Results_2010.csv")

# %%
y=pd.read_csv("Bihar_Election_Results_2015.csv")

# %%
z=pd.read_csv("Bihar_Election_Results_2005_Oct.csv")

# %%
w=pd.read_csv("Bihar_Election_Results_2005_Feb.csv")

# %%
x.shape
# Out:
# (3523, 8)

# %%
y.shape
# Out:
# (3450, 8)

# %%
z.shape
# Out:
# (2135, 8)

# %%
w.shape
# Out:
# (3193, 8)

# %%
a = pd.DataFrame()

# %%
b = pd.DataFrame()

# %%
c = pd.DataFrame()

# %%
d = pd.DataFrame()

# %%
for i in range(3523) :
    if x.loc[i].Position == 1 :
      a = a.append(x.loc[i])

# %%
for i in range(3450) :
    if y.loc[i].Position == 1 :
      b = b.append(y.loc[i])

# %%
for r in range(2135) :
    if z.loc[r].Position == 1 :
      c = c.append(z.loc[r])

# %%
for i in range(3193) :
    if w.loc[i].Position == 1 :
      d = d.append(w.loc[i])

# %%
a.shape, b.shape, c.shape, d.shape
# Out:
# ((243, 9), (243, 9), (243, 9), (243, 9))

# %%
l = pd.DataFrame()

# %%
for i in range(243) :
    if a.iloc[i].Party == b.iloc[i].Party :
        if a.iloc[i].Party == b.iloc[i].Party :
            if a.iloc[i].Party == b.iloc[i].Party :
                l = l.append(a.iloc[i])

# %%
df1 = pd.DataFrame(data=l)
print (df1["Party"].to_string(index = False))
# Out:
#     Bharatiya Janta Party
#     Bharatiya Janta Party
#     Bharatiya Janta Party
#     Bharatiya Janta Party
#     Bharatiya Janta Party
#     Bharatiya Janta Party
#       Janata Dal (United)
#     Bharatiya Janta Party
#     Bharatiya Janta Party
#       Janata Dal (United)
#       Janata Dal (United)
#      Rashtriya Janata Dal
#       Janata Dal (United)
#       Janata Dal (United)
#       Janata Dal (United)
#       Janata Dal (United)
#       Janata Dal (United)
#     Bharatiya Janta Party
#       Janata Dal (United)
#     Bharatiya Janta Party
#  Indian National Congress
#  Indian National Congress
#  Indian National Congress
#     Bharatiya Janta Party
#       Janata Dal (United)
#       Janata Dal (United)
#     Bharatiya Janta Party
#     Bharatiya Janta Party
#     Bharatiya Janta Party
#       Janata Dal (United)
#       Janata Dal (United)
#       Janata Dal (United)
#      Rashtriya Janata Dal
#       Janata Dal (United)
#       Janata Dal (United)
# ...

# %%
for i in range(3523) :
    if x.loc[i].Position == 1 :
        if (x.loc[i].Voteper-x.loc[i+1].Voteper) < 10 :
            a = a.append(x.loc[i])

# %%
for i in range(3450) :
    if y.loc[i].Position == 1 :
        if (y.loc[i].Voteper-y.loc[i+1].Voteper) < 10 :
             b = b.append(y.loc[i])

# %%
for i in range(2135) :
    if z.loc[i].Position == 1 :
        if (z.loc[i].Voteper-z.loc[i+1].Voteper) < 10 :
            c = c.append(z.loc[i])

# %%
for i in range(3193) :
    if w.loc[i].Position == 1 :
        if (w.loc[i].Voteper-w.loc[i+1].Voteper) < 10 :
            d = d.append(w.loc[i])

# %%
m = pd.DataFrame()

# %%
a["Party"].value_counts()
# Out:
# Janata Dal (United)         115
# Bharatiya Janta Party        91
# Rashtriya Janata Dal         22
# Independent                   6
# Indian National Congress      4
# Lok Jan Shakti Party          3
# Jharkhand Mukti Morcha        1
# Communist Party Of India      1
# Name: Party, dtype: int64

# %%
e = pd.DataFrame()

# %%
a
# Out:
#        ACNo         ACname  ElectionYear                      Name  \
# 0       1.0  Valmiki Nagar        2010.0              Rajesh Singh
# 14      2.0       Ramnagar        2010.0           Bhagirathi Devi
# 31      3.0   Narkatiaganj        2010.0      Satish Chandra Dubey
# 46      4.0         Bagaha        2010.0      Prabhat Ranjan Singh
# 61      5.0        Lauriya        2010.0              Vinay Bihari
# 73      6.0         Nautan        2010.0            Manorma Prasad
# 89      7.0      Chanpatia        2010.0         Chandra Mohan Rai
# 107     8.0        Bettiah        2010.0                 Renu Devi
# 125     9.0          Sikta        2010.0               Dilip Varma
# 143    10.0         Raxaul        2010.0      Dr. Ajay Kumar Singh
# 150    11.0        Sugauli        2010.0         Ramchandra Sahani
# 160    12.0       Narkatia        2010.0       Shyam Bihari Prasad
# 177    13.0       Harsidhi        2010.0    Krishana Nandan Paswan
# ...

# %%
e = pd.DataFrame()

# %%
for i in range(243) :
    if a.iloc[i].Party != b.iloc[i].Party :
         if a.iloc[i].Party != c.iloc[i].Party :
                if a.iloc[i].Party != d.iloc[i].Party :
                    e = e.append(a.iloc[i])

# %%
e = e.reset_index()

# %%
f = pd.DataFrame()

# %%
g = pd.DataFrame()

# %%
h = pd.DataFrame()

# %%
j = pd.DataFrame()

# %%
x
# Out:
#       ElectionYear  Position  \
# 0             2010         1
# 1             2010         2
# 2             2010         3
# 3             2010         4
# 4             2010         5
# 5             2010         6
# 6             2010         7
# 7             2010         8
# 8             2010         9
# 9             2010        10
# 10            2010        11
# 11            2010        12
# 12            2010        13
# 13            2010        14
# 14            2010         1
# 15            2010         2
# 16            2010         3
# 17            2010         4
# 18            2010         5
# 19            2010         6
# 20            2010         7
# 21            2010         8
# 22            2010         9
# 23            2010        10
# 24            2010        11
# 25            2010        12
# 26            2010        13
# 27            2010        14
# 28            2010        15
# 29            2010        16
# 30            2010        17
# ...

# %%
for i in range(3523) :
    if x.loc[i].Position == 1 :
      if x.loc[i].Voteper > 10 :
        if x.loc[i+1].Voteper > 10:
            if x.loc[i+2].Voteper > 10:
                f = f.append(x.loc[i])

# %%
for i in range(3450) :
    if y.loc[i].Position == 1 :
      if y.loc[i].Voteper > 10 :
        if y.loc[i+1].Voteper > 10:
            if y.loc[i+2].Voteper > 10:
                g = g.append(y.loc[i])

# %%
for i in range(2135) :
    if z.loc[i].Position == 1 :
      if z.loc[i].Voteper > 10 :
        if z.loc[i+1].Voteper > 10:
            if z.loc[i+2].Voteper > 10:
                h = h.append(z.loc[i])

# %%
for i in range(3193) :
    if w.loc[i].Position == 1 :
      if w.loc[i].Voteper > 10 :
        if w.loc[i+1].Voteper > 10:
            if w.loc[i+2].Voteper > 10:
                j = j.append(w.loc[i])

# %%
a.shape, b.shape, c.shape, d.shape
# Out:
# ((115, 9), (121, 9), (149, 9), (140, 9))

# %% [markdown]
# k1 = pd.DataFrame()

# %%
k2 = pd.DataFrame()

# %%
k3 = pd.DataFrame()

# %%
for p in range(115) :
   for q in range(121) :
        if a.iloc[p].ACNo == b.iloc[q].ACNo :
            k1 = k1.append(a.iloc[p])

# %%
k1.shape
# Out:
# (100, 9)

# %%
for p in range(100) :
    for r in range(149) :
      if k1.iloc[p].ACNo == c.iloc[r].ACNo :
        k2 = k2.append(k1.iloc[p])

# %%
k1.shape, k2.shape
# Out:
# ((100, 9), (69, 9))

# %%
 for p in range(69) :
    for s in range(140) :
        if k2.iloc[p].ACNo == d.iloc[s].ACNo :
            k3 = k3.append(k2.iloc[p])

# %%
df = pd.DataFrame(data=k3)
print (df["ACname"].to_string(index = False))
# Out:
#  Valmiki Nagar
#   Narkatiaganj
#        Lauriya
#       Harlakhi
#          Baisi
#      Balrampur
#        Pranpur
#        Mahishi
#        Ziradei
#        Darauli
#   Raghunathpur
#       Ujiarpur
#      Bachhwara
#         Bakhri
#          Banka
#     Sheikhpura
#        Sandesh
#         Agiaon
#     Jagdishpur
#        Ramgarh
#       Kargahar
#          Dehri
#        Karakat
#          Arwal
#          Sikta
#         Raxaul
#        Parihar
#      Sitamarhi
#       Harlakhi
#      Madhubani
#       Rajnagar
#    Bahadurganj
#     Thakurganj
#          Kasba
#        Pranpur
#          Keoti
#        Kurhani
#        Ziradei
#        Darauli
#      Pirpainti
#      Bhagalpur
#      Nathnagar
#          Banka
#         Belhar
#     Jagdishpur
#        Ramgarh
#        Mohania
#       Kargahar
#          Dehri
#        Karakat
#            Goh
#         Nawada

# %%
a1 = pd.DataFrame()
a3 = pd.DataFrame()
a2 = pd.DataFrame()
a4 = pd.DataFrame()
a5 = pd.DataFrame()
a6 = pd.DataFrame()
a7 = pd.DataFrame()
a8 = pd.DataFrame()

# %%
for i in range(3193) :
    if w.loc[i].Position == 1 :
        if w.loc[i].Party == "Rashtriya Janata Dal" :
            a1 = a1.append(w.loc[i])

# %%
for i in range(2135) :
    if z.loc[i].Position == 1 :
        if z.loc[i].Party == "Janata Dal (United)" :
            a2 = a2.append(z.loc[i])

# %%
for i in range(3523) :
    if x.loc[i].Position == 1 :
        if x.loc[i].Party == "Janata Dal (United)" :
            a3 = a3.append(x.loc[i])

# %%
for i in range(3450) :
    if y.loc[i].Position == 1 :
        if y.loc[i].Party == "Rashtriya Janata Dal" :
            a4 = a4.append(y.loc[i])

# %%
a1.shape, a2.shape, a3.shape, a4.shape
# Out:
# ((75, 9), (88, 9), (115, 9), (80, 9))

# %%
df = pd.DataFrame(data=a4)
print (df["ACname"].to_string(index = False))
# Out:
#         Narkatia
#         Harsidhi
#          Kesaria
#            Dhaka
#          Sursand
#        Sitamarhi
#      Runisaidpur
#         Khajauli
#           Bikram
#        Madhubani
#      Jhanjharpur
#            Pipra
#       Narpatganj
#            Baisi
#           Barari
#        Madhepura
#          Saharsa
#          Mahishi
#         Alinagar
#  Darbhanga Rural
#       Bahadurpur
#            Keoti
#          Gaighat
#            Aurai
#          Minapur
#            Sakra
#         Barharia
#        Sahebganj
#          Barauli
#     Raghunathpur
#      Goriyakothi
#         Baniapur
#          Taraiya
#         Marhaura
#           Garkha
#            Parsa
#          Sonepur
#       Makhdumpur
#       Raja Pakar
#         Raghopur
#          Patepur
#       Samastipur
#         Ujiarpur
#   Mohiuddinnagar
#           Teghra
#   Sahebpur Kamal
#           Bakhri
#           Alauli
#      Biharsharif
#        Pirpainti
#          Katoria
#           Munger
# ...

# %%
for i in range(98) :
    for j in range(56) :
        if a4.iloc[i].ACNo == a3.iloc[j].ACNo :
            if a4.iloc[i].Votes < a3.iloc[j].Votes :
                a5 = a5.append(a3.iloc[j])

# %%
a5.shape
# Out:
# (31, 9)

# %%
for i in range(31) :
    for j in range(35) :
        if a5.iloc[i].ACNo == a2.iloc[j].ACNo :
            if a5.iloc[i].Votes < a2.iloc[j].Votes :
                a6 = a6.append(a2.iloc[j])

# %%
a6.shape
# Out:
# (1, 9)

# %%
for i in range(1) :
    for j in range(17) :
        if a6.iloc[i].ACNo == a1.iloc[j].ACNo :
            if a6.iloc[i].Votes < a1.iloc[j].Votes :
                a7 = a7.append(a1.iloc[j])

# %%
df = pd.DataFrame(data=a7)
print (df["ACname"].to_string(index = False))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ACname'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-576-38e3a0e13df2> in <module>
#       1 df = pd.DataFrame(data=a7)
# ...

# %%
print("an (apple) (a-b) day keeps the doctor aaway")
# Out:
# an (apple) (a-b) day keeps the doctor aaway
